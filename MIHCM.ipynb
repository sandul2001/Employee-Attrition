# %%
# !pip install pandas
import pandas as pd
import numpy as np
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
data =pd.read_csv("/content/KDU DataSet - Sheet1.csv")

# %%
data.head()
# Out:
#                              EmployeeId  GenderCode GenderName Dateofbirth  \
# 0  72FFC6DE-D7D0-4B68-9B47-039F128E674A           1       Male   25/8/1992
# 1  AE76AD16-D7F3-4423-8599-04EC599A4C89           1       Male   11/4/1990
# 2  599BB5FC-347A-49BC-8971-0566A915F6BF           1       Male   6/11/1987
# 3  75C2F5F9-5299-45F3-B715-05C99175A7D1           2     Female    9/4/1997
# 4  3CD99CED-1C3B-4494-945B-060EBE6225FB           1       Male   8/11/2022
#
#    Age  Level1Code  Level2Code  Level3Code  Level4Code  JobCategoryCode  ...  \
# 0   31         NaN           6      1004.0         NaN              133  ...
# 1   33         NaN           6      1006.0        36.0              134  ...
# 2   36         NaN           6      1006.0         NaN              134  ...
# 3   26         NaN           6      1015.0        40.0              134  ...
# 4    1         NaN          11         NaN         NaN              139  ...
#
#    overtimewrknpercntage  AbsentiesmPercentageE AbsentiesmPercentageR  \
# 0                    0.0              47.663551                   NaN
# 1                    0.0                    NaN             96.825397
# 2                    NaN                    NaN                   NaN
# 3                    0.0              98.550725             69.590643
# 4                    NaN                    NaN                   NaN
#
#    AbsenteeismPercntage6  allocatedleaves  usedleaves.1  LeavePercntagenew  \
# 0              47.663551            268.0         118.5          44.216418
# 1              96.825397             38.0           3.5           9.210526
# 2                    NaN             70.0           9.5          13.571429
# 3              69.590643             49.0           4.0           8.163265
# 4                    NaN              2.0           0.0           0.000000
#
#   exs  sre sumofshrtlvehrs6
# 0 NaN  NaN              NaN
# 1 NaN  NaN              NaN
# 2 NaN  NaN              NaN
# 3 NaN  NaN              NaN
# 4 NaN  NaN              NaN
#
# [5 rows x 83 columns]

# %%
data.shape
# Out:
# (290, 83)

# %%
data
# Out:
#                                EmployeeId  GenderCode GenderName Dateofbirth  \
# 0    72FFC6DE-D7D0-4B68-9B47-039F128E674A           1       Male   25/8/1992
# 1    AE76AD16-D7F3-4423-8599-04EC599A4C89           1       Male   11/4/1990
# 2    599BB5FC-347A-49BC-8971-0566A915F6BF           1       Male   6/11/1987
# 3    75C2F5F9-5299-45F3-B715-05C99175A7D1           2     Female    9/4/1997
# 4    3CD99CED-1C3B-4494-945B-060EBE6225FB           1       Male   8/11/2022
# ..                                    ...         ...        ...         ...
# 285  1C956E12-A65B-4368-8041-FD510D858BC2           1       Male    2/9/1989
# 286  13508280-C3C6-49A1-964D-FD8FAC6505A9           2     Female    3/6/1988
# 287  9BCEF03F-AF76-4033-B81D-FE9F1737AE69           2     Female    8/3/1993
# 288  F72A8F4F-2390-4BB8-849A-FEA0C257D815           1       Male   12/5/1987
# 289  BBE5F078-A33C-4232-A697-FFD175610EAC           1       Male    6/1/1991
#
#      Age  Level1Code  Level2Code  Level3Code  Level4Code  JobCategoryCode  \
# 0     31         NaN           6      1004.0         NaN              133
# 1     33         NaN           6      1006.0        36.0              134
# 2     36         NaN           6      1006.0         NaN              134
# 3     26         NaN           6      1015.0        40.0              134
# 4      1         NaN          11         NaN         NaN              139
# ..   ...         ...         ...         ...         ...              ...
# 285   34         NaN           6      1006.0         NaN              134
# 286   35         NaN           6      1004.0         NaN              133
# 287   30         NaN           6      1002.0         NaN              134
# 288   36         NaN           6      1004.0         NaN              133
# 289   32         NaN           7      1012.0         NaN              140
#
#      ...  overtimewrknpercntage  AbsentiesmPercentageE AbsentiesmPercentageR  \
# 0    ...                    0.0              47.663551                   NaN
# 1    ...                    0.0                    NaN             96.825397
# 2    ...                    NaN                    NaN                   NaN
# 3    ...                    0.0              98.550725             69.590643
# 4    ...                    NaN                    NaN                   NaN
# ..   ...                    ...                    ...                   ...
# 285  ...                    NaN                    NaN                   NaN
# 286  ...                    0.0                    NaN             40.000000
# 287  ...                    NaN                    NaN                   NaN
# 288  ...                    0.0                    NaN             97.080292
# 289  ...                    0.0                    NaN            100.000000
#
#      AbsenteeismPercntage6  allocatedleaves  usedleaves.1  LeavePercntagenew  \
# 0                47.663551            268.0         118.5          44.216418
# 1                96.825397             38.0           3.5           9.210526
# 2                      NaN             70.0           9.5          13.571429
# 3                69.590643             49.0           4.0           8.163265
# 4                      NaN              2.0           0.0           0.000000
# ..                     ...              ...           ...                ...
# 285                    NaN              2.5           0.0           0.000000
# 286              40.000000            216.0          89.0          41.203704
# 287                    NaN             70.0           1.0           1.428571
# 288              97.080292            311.0          72.5          23.311897
# 289             100.000000             91.0           0.0           0.000000
#
#     exs  sre sumofshrtlvehrs6
# 0   NaN  NaN              NaN
# 1   NaN  NaN              NaN
# 2   NaN  NaN              NaN
# 3   NaN  NaN              NaN
# 4   NaN  NaN              NaN
# ..   ..  ...              ...
# 285 NaN  NaN              NaN
# 286 NaN  NaN              NaN
# 287 NaN  NaN              NaN
# 288 NaN  NaN              NaN
# 289 NaN  NaN              NaN
#
# [290 rows x 83 columns]

# %%
data.columns
# Out:
# Index(['EmployeeId', 'GenderCode', 'GenderName', 'Dateofbirth', 'Age',
#        'Level1Code', 'Level2Code', 'Level3Code', 'Level4Code',
#        'JobCategoryCode', 'UnionMember', 'UnionStatus', 'DateOfAppointment',
#        'DesignationCode', 'tenure', 'Salary', 'Overtime', 'A_ResignedDate',
#        'TravelModeCode', 'TravelMethodName', 'A_DateOfRetirement', 'Deleted',
#        'deleted_resign', 'GradeCode', 'EmploymentTypeCode', 'Category',
#        'AvgFinalScore', 'PromotionTypeName', 'PromotionTypeId',
#        'maxeffectdate', 'ResignationTypeId', 'ResignationTypeName',
#        'WorkingYears', 'NoOfCompaniesWorked', 'Average_LeavesPerMonth',
#        'ReportingPersonCode', 'ReportingDesignationCode', 'PromotionDate',
#        'MonthsinceLastpromotion2', 'OldDesignationCode', 'OldCategoryCode',
#        'OldGradeCode', 'latestpromotionday', 'allocated_leaves', 'usedleaves',
#        'leave_PercentagALL', 'AbsentiesmPercentage', 'AverageMonthlyWorkhrs',
#        'AvgOverTimeRate', 'avgyearlyhrsholidyhrsworked',
#        'HolidayworkingPercentage', 'avgyearlynoOfHolidaysworked',
#        'avgyearlywkndhrsworked', 'avgnofwkndsworked',
#        'weekendworkingPercentage', 'AvgShrtlveHrs', 'expectdwrkhrsR',
#        'expectdwrkhrsEX', 'sumofworkhrsRe', 'sumofworkhrsEx',
#        'Workinghrpercentage', 'sumwrhrsR', 'sumwrhrsE', 'noofweekendswrkd6E',
#        'noofweekendswrkd6R', 'wkendwrkpercntage', 'Noofweekendsworked6',
#        'sumwrholihre', 'sumwrholihrex', 'holidywrkpercentage6',
#        'noofholidaysworked6', 'sumOverTimeRate6monthsE',
#        'sumOverTimeRate6monthsR', 'overtimewrknpercntage',
#        'AbsentiesmPercentageE', 'AbsentiesmPercentageR',
#        'AbsenteeismPercntage6', 'allocatedleaves', 'usedleaves.1',
#        'LeavePercntagenew', 'exs', 'sre', 'sumofshrtlvehrs6'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 83 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   EmployeeId                   290 non-null    object
#  1   GenderCode                   290 non-null    int64
#  2   GenderName                   290 non-null    object
#  3   Dateofbirth                  290 non-null    object
#  4   Age                          290 non-null    int64
#  5   Level1Code                   0 non-null      float64
#  6   Level2Code                   290 non-null    int64
#  7   Level3Code                   237 non-null    float64
#  8   Level4Code                   72 non-null     float64
#  9   JobCategoryCode              290 non-null    int64
#  10  UnionMember                  290 non-null    int64
#  11  UnionStatus                  290 non-null    int64
#  12  DateOfAppointment            290 non-null    object
#  13  DesignationCode              290 non-null    int64
#  14  tenure                       290 non-null    int64
#  15  Salary                       290 non-null    int64
#  16  Overtime                     290 non-null    int64
#  17  A_ResignedDate               290 non-null    object
#  18  TravelModeCode               290 non-null    int64
#  19  TravelMethodName             97 non-null     object
#  20  A_DateOfRetirement           290 non-null    object
#  21  Deleted                      290 non-null    int64
#  22  deleted_resign               177 non-null    float64
#  23  GradeCode                    290 non-null    int64
#  24  EmploymentTypeCode           290 non-null    int64
#  25  Category                     290 non-null    object
#  26  AvgFinalScore                132 non-null    float64
#  27  PromotionTypeName            62 non-null     object
#  28  PromotionTypeId              62 non-null     float64
#  29  maxeffectdate                177 non-null    object
#  30  ResignationTypeId            177 non-null    float64
#  31  ResignationTypeName          177 non-null    object
#  32  WorkingYears                 102 non-null    float64
#  33  NoOfCompaniesWorked          102 non-null    float64
#  34  Average_LeavesPerMonth       211 non-null    float64
#  35  ReportingPersonCode          290 non-null    int64
#  36  ReportingDesignationCode     290 non-null    int64
#  37  PromotionDate                62 non-null     object
#  38  MonthsinceLastpromotion2     62 non-null     float64
#  39  OldDesignationCode           62 non-null     float64
#  40  OldCategoryCode              62 non-null     float64
#  41  OldGradeCode                 62 non-null     float64
#  42  latestpromotionday           62 non-null     object
#  43  allocated_leaves             284 non-null    float64
#  44  usedleaves                   284 non-null    float64
#  45  leave_PercentagALL           284 non-null    float64
#  46  AbsentiesmPercentage         247 non-null    float64
#  47  AverageMonthlyWorkhrs        247 non-null    float64
#  48  AvgOverTimeRate              247 non-null    float64
#  49  avgyearlyhrsholidyhrsworked  137 non-null    float64
#  50  HolidayworkingPercentage     247 non-null    float64
#  51  avgyearlynoOfHolidaysworked  137 non-null    float64
#  52  avgyearlywkndhrsworked       156 non-null    float64
#  53  avgnofwkndsworked            156 non-null    float64
#  54  weekendworkingPercentage     247 non-null    float64
#  55  AvgShrtlveHrs                0 non-null      float64
#  56  expectdwrkhrsR               123 non-null    float64
#  57  expectdwrkhrsEX              123 non-null    float64
#  58  sumofworkhrsRe               123 non-null    float64
#  59  sumofworkhrsEx               123 non-null    float64
#  60  Workinghrpercentage          218 non-null    float64
#  61  sumwrhrsR                    43 non-null     float64
#  62  sumwrhrsE                    29 non-null     float64
#  63  noofweekendswrkd6E           29 non-null     float64
#  64  noofweekendswrkd6R           43 non-null     float64
#  65  wkendwrkpercntage            149 non-null    float64
#  66  Noofweekendsworked6          71 non-null     float64
#  67  sumwrholihre                 28 non-null     float64
#  68  sumwrholihrex                54 non-null     float64
#  69  holidywrkpercentage6         78 non-null     float64
#  70  noofholidaysworked6          78 non-null     float64
#  71  sumOverTimeRate6monthsE      123 non-null    float64
#  72  sumOverTimeRate6monthsR      123 non-null    float64
#  73  overtimewrknpercntage        218 non-null    float64
#  74  AbsentiesmPercentageE        123 non-null    float64
#  75  AbsentiesmPercentageR        123 non-null    float64
#  76  AbsenteeismPercntage6        218 non-null    float64
#  77  allocatedleaves              284 non-null    float64
#  78  usedleaves.1                 284 non-null    float64
#  79  LeavePercntagenew            284 non-null    float64
#  80  exs                          0 non-null      float64
#  81  sre                          0 non-null      float64
#  82  sumofshrtlvehrs6             0 non-null      float64
# dtypes: float64(54), int64(16), object(13)
# memory usage: 188.2+ KB

# %%
data.describe()
# Out:
#        GenderCode         Age  Level1Code  Level2Code   Level3Code  \
# count  290.000000  290.000000         0.0  290.000000   237.000000
# mean     1.393103   29.789655         NaN    6.644828  1006.658228
# std      0.489284   11.089159         NaN    1.220382     3.556634
# min      1.000000    0.000000         NaN    6.000000  1001.000000
# 25%      1.000000   27.000000         NaN    6.000000  1004.000000
# 50%      1.000000   31.000000         NaN    6.000000  1006.000000
# 75%      2.000000   35.000000         NaN    7.000000  1009.000000
# max      2.000000   64.000000         NaN   11.000000  1017.000000
#
#        Level4Code  JobCategoryCode  UnionMember  UnionStatus  DesignationCode  \
# count   72.000000       290.000000        290.0        290.0       290.000000
# mean    36.888889       135.244828          0.0          0.0      9031.189655
# std      3.014311         2.963222          0.0          0.0        61.987011
# min     33.000000       129.000000          0.0          0.0      8935.000000
# 25%     34.000000       134.000000          0.0          0.0      8976.000000
# 50%     37.000000       134.000000          0.0          0.0      9032.000000
# 75%     37.500000       139.000000          0.0          0.0      9072.250000
# max     43.000000       140.000000          0.0          0.0      9162.000000
#
#        ...  overtimewrknpercntage  AbsentiesmPercentageE  \
# count  ...                  218.0             123.000000
# mean   ...                    0.0              37.690880
# std    ...                    0.0              36.163349
# min    ...                    0.0               0.000000
# 25%    ...                    0.0               8.411215
# 50%    ...                    0.0              19.298246
# 75%    ...                    0.0              63.126593
# max    ...                    0.0             100.000000
#
#        AbsentiesmPercentageR  AbsenteeismPercntage6  allocatedleaves  \
# count             123.000000             218.000000       284.000000
# mean               42.895680              36.835303        98.607394
# std                30.420704              32.042004       116.169487
# min                 1.398601               0.000000         0.000000
# 25%                18.762320              10.955912        21.375000
# 50%                32.065217              23.552747        54.000000
# 75%                67.264566              57.055367       111.250000
# max               100.000000             100.000000       537.000000
#
#        usedleaves.1  LeavePercntagenew  exs  sre  sumofshrtlvehrs6
# count    284.000000         284.000000  0.0  0.0               0.0
# mean      26.640454          22.127059  NaN  NaN               NaN
# std       43.775304          22.072078  NaN  NaN               NaN
# min        0.000000           0.000000  NaN  NaN               NaN
# 25%        0.500000           1.827731  NaN  NaN               NaN
# 50%        8.000000          16.333333  NaN  NaN               NaN
# 75%       32.000000          35.736332  NaN  NaN               NaN
# max      367.500000         120.000000  NaN  NaN               NaN
#
# [8 rows x 70 columns]

# %%
data.isnull().sum()
# Out:
# EmployeeId             0
# GenderCode             0
# GenderName             0
# Dateofbirth            0
# Age                    0
#                     ...
# usedleaves.1           6
# LeavePercntagenew      6
# exs                  290
# sre                  290
# sumofshrtlvehrs6     290
# Length: 83, dtype: int64

# %%
# Assuming your dataset is stored in a DataFrame named 'data'
employee_ids = [
    "F9FADDE1-995A-4FC6-A388-19C2149A71DB",
    "25083D48-1EB1-4541-8FA6-C3993EC700FF",
    "BB279AE7-7B24-454C-9611-9F63E3363522",
    "E6B4B54E-E80F-4249-8E2E-3052DD1114AA",
    "22028EEA-B141-4C3B-A46D-60071CA0AF34",
    "711E1F3D-E507-42E3-B794-818DD208935F"
]

# Remove rows based on employee IDs
data = data[~data['EmployeeId'].isin(employee_ids)]

# Displaying the updated dataset
print(data)
# Out:
#                                EmployeeId  GenderCode GenderName Dateofbirth  \
# 0    72FFC6DE-D7D0-4B68-9B47-039F128E674A           1       Male   25/8/1992
# 1    AE76AD16-D7F3-4423-8599-04EC599A4C89           1       Male   11/4/1990
# 2    599BB5FC-347A-49BC-8971-0566A915F6BF           1       Male   6/11/1987
# 3    75C2F5F9-5299-45F3-B715-05C99175A7D1           2     Female    9/4/1997
# 4    3CD99CED-1C3B-4494-945B-060EBE6225FB           1       Male   8/11/2022
# ..                                    ...         ...        ...         ...
# 285  1C956E12-A65B-4368-8041-FD510D858BC2           1       Male    2/9/1989
# 286  13508280-C3C6-49A1-964D-FD8FAC6505A9           2     Female    3/6/1988
# 287  9BCEF03F-AF76-4033-B81D-FE9F1737AE69           2     Female    8/3/1993
# 288  F72A8F4F-2390-4BB8-849A-FEA0C257D815           1       Male   12/5/1987
# 289  BBE5F078-A33C-4232-A697-FFD175610EAC           1       Male    6/1/1991
#
#      Age  Level1Code  Level2Code  Level3Code  Level4Code  JobCategoryCode  \
# 0     31         NaN           6      1004.0         NaN              133
# 1     33         NaN           6      1006.0        36.0              134
# 2     36         NaN           6      1006.0         NaN              134
# 3     26         NaN           6      1015.0        40.0              134
# 4      1         NaN          11         NaN         NaN              139
# ..   ...         ...         ...         ...         ...              ...
# 285   34         NaN           6      1006.0         NaN              134
# 286   35         NaN           6      1004.0         NaN              133
# 287   30         NaN           6      1002.0         NaN              134
# 288   36         NaN           6      1004.0         NaN              133
# 289   32         NaN           7      1012.0         NaN              140
#
#      ...  overtimewrknpercntage  AbsentiesmPercentageE AbsentiesmPercentageR  \
# 0    ...                    0.0              47.663551                   NaN
# 1    ...                    0.0                    NaN             96.825397
# 2    ...                    NaN                    NaN                   NaN
# 3    ...                    0.0              98.550725             69.590643
# 4    ...                    NaN                    NaN                   NaN
# ..   ...                    ...                    ...                   ...
# 285  ...                    NaN                    NaN                   NaN
# 286  ...                    0.0                    NaN             40.000000
# 287  ...                    NaN                    NaN                   NaN
# 288  ...                    0.0                    NaN             97.080292
# 289  ...                    0.0                    NaN            100.000000
#
#      AbsenteeismPercntage6  allocatedleaves  usedleaves.1  LeavePercntagenew  \
# 0                47.663551            268.0         118.5          44.216418
# 1                96.825397             38.0           3.5           9.210526
# 2                      NaN             70.0           9.5          13.571429
# 3                69.590643             49.0           4.0           8.163265
# 4                      NaN              2.0           0.0           0.000000
# ..                     ...              ...           ...                ...
# 285                    NaN              2.5           0.0           0.000000
# 286              40.000000            216.0          89.0          41.203704
# 287                    NaN             70.0           1.0           1.428571
# 288              97.080292            311.0          72.5          23.311897
# 289             100.000000             91.0           0.0           0.000000
#
#     exs  sre sumofshrtlvehrs6
# 0   NaN  NaN              NaN
# 1   NaN  NaN              NaN
# 2   NaN  NaN              NaN
# 3   NaN  NaN              NaN
# 4   NaN  NaN              NaN
# ..   ..  ...              ...
# 285 NaN  NaN              NaN
# 286 NaN  NaN              NaN
# 287 NaN  NaN              NaN
# 288 NaN  NaN              NaN
# 289 NaN  NaN              NaN
#
# [284 rows x 83 columns]

# %%
data.shape
# Out:
# (284, 83)

# %%
data.describe()
# Out:
#        GenderCode         Age  Level1Code  Level2Code   Level3Code  \
# count  284.000000  284.000000         0.0  284.000000   231.000000
# mean     1.390845   29.792254         NaN    6.654930  1006.683983
# std      0.488801   11.199562         NaN    1.230047     3.558169
# min      1.000000    0.000000         NaN    6.000000  1001.000000
# 25%      1.000000   27.000000         NaN    6.000000  1004.000000
# 50%      1.000000   31.000000         NaN    6.000000  1006.000000
# 75%      2.000000   35.000000         NaN    7.000000  1009.000000
# max      2.000000   64.000000         NaN   11.000000  1017.000000
#
#        Level4Code  JobCategoryCode  UnionMember  UnionStatus  DesignationCode  \
# count   72.000000       284.000000        284.0        284.0       284.000000
# mean    36.888889       135.253521          0.0          0.0      9031.855634
# std      3.014311         2.981537          0.0          0.0        62.225995
# min     33.000000       129.000000          0.0          0.0      8935.000000
# 25%     34.000000       134.000000          0.0          0.0      8976.000000
# 50%     37.000000       134.000000          0.0          0.0      9032.000000
# 75%     37.500000       139.000000          0.0          0.0      9073.000000
# max     43.000000       140.000000          0.0          0.0      9162.000000
#
#        ...  overtimewrknpercntage  AbsentiesmPercentageE  \
# count  ...                  218.0             123.000000
# mean   ...                    0.0              37.690880
# std    ...                    0.0              36.163349
# min    ...                    0.0               0.000000
# 25%    ...                    0.0               8.411215
# 50%    ...                    0.0              19.298246
# 75%    ...                    0.0              63.126593
# max    ...                    0.0             100.000000
#
#        AbsentiesmPercentageR  AbsenteeismPercntage6  allocatedleaves  \
# count             123.000000             218.000000       284.000000
# mean               42.895680              36.835303        98.607394
# std                30.420704              32.042004       116.169487
# min                 1.398601               0.000000         0.000000
# 25%                18.762320              10.955912        21.375000
# 50%                32.065217              23.552747        54.000000
# 75%                67.264566              57.055367       111.250000
# max               100.000000             100.000000       537.000000
#
#        usedleaves.1  LeavePercntagenew  exs  sre  sumofshrtlvehrs6
# count    284.000000         284.000000  0.0  0.0               0.0
# mean      26.640454          22.127059  NaN  NaN               NaN
# std       43.775304          22.072078  NaN  NaN               NaN
# min        0.000000           0.000000  NaN  NaN               NaN
# 25%        0.500000           1.827731  NaN  NaN               NaN
# 50%        8.000000          16.333333  NaN  NaN               NaN
# 75%       32.000000          35.736332  NaN  NaN               NaN
# max      367.500000         120.000000  NaN  NaN               NaN
#
# [8 rows x 70 columns]

# %%
data = data.rename(columns={'Deleted': 'Resign'})

# %%
data['Resign'].describe() #y variable
# Out:
# count    284.000000
# mean       0.602113
# std        0.490326
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: Resign, dtype: float64

# %%
data['Age'].describe()
# Out:
# count    284.000000
# mean      29.792254
# std       11.199562
# min        0.000000
# 25%       27.000000
# 50%       31.000000
# 75%       35.000000
# max       64.000000
# Name: Age, dtype: float64

# %%
data = data.drop(columns=['GenderName'
,'Dateofbirth'
,'Level1Code' #0
,'Level4Code' #72
,'UnionMember' #0
,'UnionStatus' #0
,'Salary' #0
,'Overtime' #0
,'TravelMethodName'
,'AvgFinalScore' #132
,'PromotionTypeName' #62

,'maxeffectdate' #177
,'deleted_resign'  #0
,'GradeCode' #0
,'ResignationTypeName' #177
,'PromotionDate' #62
,'OldDesignationCode' #62
,'OldCategoryCode' #62
,'OldGradeCode' #62
,'latestpromotionday' #62
,'avgyearlyhrsholidyhrsworked' #137
,'avgyearlynoOfHolidaysworked' #137
,'avgyearlywkndhrsworked' #156
,'avgnofwkndsworked'  #156
,'AvgShrtlveHrs' #0
,'expectdwrkhrsR'  #123
,'expectdwrkhrsEX' #123
,'sumofworkhrsRe' #123
,'sumofworkhrsEx' #129
,'sumwrhrsR' #43
,'sumwrhrsE' #29
,'noofweekendswrkd6E' #29
,'noofweekendswrkd6R' #43
,'Noofweekendsworked6'  #71
,'sumwrholihre'  #28
,'sumwrholihrex' #54
,'holidywrkpercentage6' #78
,'noofholidaysworked6' #78
,'sumOverTimeRate6monthsE' #123
,'sumOverTimeRate6monthsR' #123
,'overtimewrknpercntage'  #218
,'exs' #0
,'sre' #0
,'sumofshrtlvehrs6'
,'ResignationTypeId'])

# %%
data.columns
# Out:
# Index(['EmployeeId', 'GenderCode', 'Age', 'Level2Code', 'Level3Code',
#        'JobCategoryCode', 'DateOfAppointment', 'DesignationCode', 'tenure',
#        'A_ResignedDate', 'TravelModeCode', 'A_DateOfRetirement', 'Resign',
#        'EmploymentTypeCode', 'Category', 'PromotionTypeId', 'WorkingYears',
#        'NoOfCompaniesWorked', 'Average_LeavesPerMonth', 'ReportingPersonCode',
#        'ReportingDesignationCode', 'MonthsinceLastpromotion2',
#        'allocated_leaves', 'usedleaves', 'leave_PercentagALL',
#        'AbsentiesmPercentage', 'AverageMonthlyWorkhrs', 'AvgOverTimeRate',
#        'HolidayworkingPercentage', 'weekendworkingPercentage',
#        'Workinghrpercentage', 'wkendwrkpercntage', 'AbsentiesmPercentageE',
#        'AbsentiesmPercentageR', 'AbsenteeismPercntage6', 'allocatedleaves',
#        'usedleaves.1', 'LeavePercntagenew'],
#       dtype='object')

# %%
data.describe(include=['object'])
# Out:
#                                   EmployeeId DateOfAppointment A_ResignedDate  \
# count                                    284               284            284
# unique                                   284               202            142
# top     72FFC6DE-D7D0-4B68-9B47-039F128E674A          1/7/2021       1/1/1901
# freq                                       1                 7            120
#
#        A_DateOfRetirement Category
# count                 284      284
# unique                218        4
# top              1/1/1901      PER
# freq                   57      173

# %%
from google.colab import data_table
data_table.enable_dataframe_formatter()
from google.colab import data_table
data_table.disable_dataframe_formatter()

# %%
# Define a function to convert numbers to 0 if they are not 0, 1, or 2
def convert_to_zero(num):
    if num not in [0, 1, 2]:
        return 0
    return num

# Apply the conversion function to the 'travelmodecode' column
data['TravelModeCode'] = data['TravelModeCode'].apply(convert_to_zero)

# %%
mode_level3code = data['Level3Code'].mode()[0]

# Replace null values with the mode
data['Level3Code'].fillna(mode_level3code, inplace=True)

# %%
# Replace negative values with 0 in the 'tenure' column
data.loc[data['tenure'] < 0, 'tenure'] = 0

# %%
# Calculate the mean of the 'Average_LeavesPerMonth' column
mean_leaves = data['Average_LeavesPerMonth'].mean()

# Replace null values with the mean
data['Average_LeavesPerMonth'].fillna(mean_leaves, inplace=True)

# %%
# Calculate the mode of the 'ReportingPersonCode' column
mode_reporting_person_code = data['ReportingPersonCode'].mode()[0]

# Replace 0 values with the mode
data.loc[data['ReportingPersonCode'] == 0, 'ReportingPersonCode'] = mode_reporting_person_code

# %%
# Calculate the mean of the 'AverageMonthlyWorkhrs' column
mean_work_hours = data['AverageMonthlyWorkhrs'].mean()

# Replace null values with the mean
data['AverageMonthlyWorkhrs'].fillna(mean_work_hours, inplace=True)

# %%
# Calculate the mean of the 'HolidayworkingPercentage' column
mean_holiday_percentage = data['HolidayworkingPercentage'].mean()

# Replace null values with the mean
data['HolidayworkingPercentage'].fillna(mean_holiday_percentage, inplace=True)

# %%
# Replace null values with 0 in the 'PromotionTypeId' column
data['PromotionTypeId'].fillna(0, inplace=True)

# %%
#convert into numaric
data['Category'] = data['Category'].replace(['PER', 'PROB', 'CON', 'CAS'], [0, 1, 2, 3])
data['Category']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 285    1
# 286    0
# 287    0
# 288    0
# 289    1
# Name: Category, Length: 284, dtype: int64

# %%
data['AbsentiesmPercentage'].describe()
# Out:
# count    244.000000
# mean      37.937293
# std       27.630017
# min        0.783290
# 25%       15.357906
# 50%       31.969126
# 75%       52.914868
# max      100.000000
# Name: AbsentiesmPercentage, dtype: float64

# %%
# Calculate the mean of the 'AbsentiesmPercentage' column
mean_absentiesm = data['AbsentiesmPercentage'].mean()

# Replace null values with the mean
data['AbsentiesmPercentage'].fillna(mean_absentiesm, inplace=True)

# %%
data['AbsentiesmPercentage'].describe()
# Out:
# count    284.000000
# mean      37.937293
# std       25.603012
# min        0.783290
# 25%       18.035310
# 50%       36.543450
# 75%       50.000000
# max      100.000000
# Name: AbsentiesmPercentage, dtype: float64

# %%
data['weekendworkingPercentage'].describe()
# Out:
# count    244.000000
# mean       4.489224
# std       14.949717
# min        0.000000
# 25%        0.000000
# 50%        0.716855
# 75%        2.111061
# max      100.000000
# Name: weekendworkingPercentage, dtype: float64

# %%
data.isnull().sum()
# Out:
# EmployeeId                    0
# GenderCode                    0
# Age                           0
# Level2Code                    0
# Level3Code                    0
# JobCategoryCode               0
# DateOfAppointment             0
# DesignationCode               0
# tenure                        0
# A_ResignedDate                0
# TravelModeCode                0
# A_DateOfRetirement            0
# Resign                        0
# EmploymentTypeCode            0
# Category                      0
# PromotionTypeId               0
# WorkingYears                183
# NoOfCompaniesWorked         183
# Average_LeavesPerMonth        0
# ReportingPersonCode           0
# ReportingDesignationCode      0
# MonthsinceLastpromotion2    222
# allocated_leaves              0
# usedleaves                    0
# leave_PercentagALL            0
# AbsentiesmPercentage          0
# AverageMonthlyWorkhrs         0
# AvgOverTimeRate              40
# HolidayworkingPercentage      0
# weekendworkingPercentage     40
# Workinghrpercentage          66
# wkendwrkpercntage           135
# AbsentiesmPercentageE       161
# AbsentiesmPercentageR       161
# AbsenteeismPercntage6        66
# allocatedleaves               0
# usedleaves.1                  0
# LeavePercntagenew             0
# dtype: int64

# %%
threshold = 35
null_counts = data.isnull().sum()
columns_to_drop = null_counts[null_counts > threshold].index.tolist()
data = data.drop(columns=columns_to_drop)

# %%
data.isnull().sum()
# Out:
# EmployeeId                  0
# GenderCode                  0
# Age                         0
# Level2Code                  0
# Level3Code                  0
# JobCategoryCode             0
# DateOfAppointment           0
# DesignationCode             0
# tenure                      0
# A_ResignedDate              0
# TravelModeCode              0
# A_DateOfRetirement          0
# Resign                      0
# EmploymentTypeCode          0
# Category                    0
# PromotionTypeId             0
# Average_LeavesPerMonth      0
# ReportingPersonCode         0
# ReportingDesignationCode    0
# allocated_leaves            0
# usedleaves                  0
# leave_PercentagALL          0
# AbsentiesmPercentage        0
# AverageMonthlyWorkhrs       0
# HolidayworkingPercentage    0
# allocatedleaves             0
# usedleaves.1                0
# LeavePercntagenew           0
# dtype: int64

# %%
count = len(data[data['Resign'] == 0])
print(count)
# Out:
# 113

# %%
count = len(data[data['Resign'] == 1])
print(count)
# Out:
# 171

# %%
haveduprows = data.duplicated().any()
haveduprows
# Out:
# False

# %%
def normalize_column_z_score(dataframe, column_name):
    column_data = dataframe[column_name]
    mean_val = column_data.mean()
    std_val = column_data.std()
    normalized_column = (column_data - mean_val) / std_val
    dataframe[column_name] = normalized_column

# %%
column_name = 'AbsentiesmPercentage'  # Replace with the column name to be normalized

normalize_column_z_score(data, column_name)

# %%
column_name = 'leave_PercentagALL'  # Replace with the column name to be normalized

normalize_column_z_score(data, column_name)

# %%
column_name = 'Average_LeavesPerMonth'  # Replace with the column name to be normalized

normalize_column_z_score(data, column_name)

# %%
column_name = 'HolidayworkingPercentage'  # Replace with the column name to be normalized

normalize_column_z_score(data, column_name)

# %%
numeric_df = data.select_dtypes(include=['number'])
numeric_df
# Out:
#      GenderCode  Age  Level2Code  Level3Code  JobCategoryCode  \
# 0             1   31           6      1004.0              133
# 1             1   33           6      1006.0              134
# 2             1   36           6      1006.0              134
# 3             2   26           6      1015.0              134
# 4             1    1          11      1006.0              139
# ..          ...  ...         ...         ...              ...
# 285           1   34           6      1006.0              134
# 286           2   35           6      1004.0              133
# 287           2   30           6      1002.0              134
# 288           1   36           6      1004.0              133
# 289           1   32           7      1012.0              140
#
#      DesignationCode  tenure  TravelModeCode  Resign  EmploymentTypeCode  ...  \
# 0               9032       8               2       0                  54  ...
# 1               8935       1               0       1                  54  ...
# 2               8935       3               0       1                  54  ...
# 3               9057       1               0       1                  54  ...
# 4               9000       0               0       0                  97  ...
# ..               ...     ...             ...     ...                 ...  ...
# 285             8935       0               0       1                  47  ...
# 286             9008       6               2       1                  54  ...
# 287             8982       1               0       1                  54  ...
# 288             9089       9               2       1                  54  ...
# 289             9027       2               0       1                  47  ...
#
#      ReportingDesignationCode  allocated_leaves  usedleaves  \
# 0                        8986             268.0       118.5
# 1                        9087              38.0         3.5
# 2                        8977              70.0         9.5
# 3                        9128              49.0         4.0
# 4                        9150               2.0         0.0
# ..                        ...               ...         ...
# 285                      9017               2.5         0.0
# 286                      9008             216.0        89.0
# 287                      8954              70.0         1.0
# 288                      8986             311.0        72.5
# 289                      8986              91.0         0.0
#
#      leave_PercentagALL  AbsentiesmPercentage  AverageMonthlyWorkhrs  \
# 0              0.996704             -0.133324             472.020000
# 1             -0.586198              2.232176               3.560000
# 2             -0.389006              0.000000             166.585574
# 3             -0.633553              0.203408             189.060000
# 4             -1.002681              0.000000             166.585574
# ..                  ...                   ...                    ...
# 285           -1.002681              1.177510              23.460000
# 286            0.860475             -0.012414             143.810000
# 287           -0.938084              0.000000             166.585574
# 288            0.051440              0.495990             247.130000
# 289           -1.002681              2.424039               0.000000
#
#      HolidayworkingPercentage  allocatedleaves  usedleaves.1  \
# 0                   -0.364626            268.0         118.5
# 1                   -0.568251             38.0           3.5
# 2                    0.000000             70.0           9.5
# 3                    0.024114             49.0           4.0
# 4                    0.000000              2.0           0.0
# ..                        ...              ...           ...
# 285                 -0.568251              2.5           0.0
# 286                 -0.568251            216.0          89.0
# 287                  0.000000             70.0           1.0
# 288                 -0.568251            311.0          72.5
# 289                 -0.568251             91.0           0.0
#
#      LeavePercntagenew
# 0            44.216418
# 1             9.210526
# 2            13.571429
# 3             8.163265
# 4             0.000000
# ..                 ...
# 285           0.000000
# 286          41.203704
# 287           1.428571
# 288          23.311897
# 289           0.000000
#
# [284 rows x 24 columns]

# %%
from scipy.stats import spearmanr

# %%
# Use the .corr() function to calculate the Pearson correlation coefficient
correlation_coefficient = data['Resign'].corr(data['Age'])
correlation_coefficient
# Out:
# 0.21525624620870393

# %%
selected_columnsA = ['Resign','Level2Code','JobCategoryCode','tenure','DesignationCode','EmploymentTypeCode','ReportingPersonCode', 'Category','AbsentiesmPercentage','PromotionTypeId',
                    'ReportingDesignationCode','AverageMonthlyWorkhrs','HolidayworkingPercentage','GenderCode', 'Age','Level3Code', 'TravelModeCode','Average_LeavesPerMonth','allocated_leaves','usedleaves','LeavePercntagenew','leave_PercentagALL' ]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
correlation_matrix = data[selected_columnsA].corr()
plt.figure(figsize=(15, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="viridis")
plt.title("Correlation Matrix")
plt.show()

# %%
selected_columnsX = ['Level2Code','JobCategoryCode','tenure','DesignationCode','EmploymentTypeCode','ReportingPersonCode','AbsentiesmPercentage','PromotionTypeId',
                    'ReportingDesignationCode','AverageMonthlyWorkhrs','HolidayworkingPercentage', 'Age','allocated_leaves','usedleaves']

# %%
data = data.drop(columns=['EmployeeId','GenderCode','Level3Code','DateOfAppointment','A_ResignedDate','A_DateOfRetirement','Category','Average_LeavesPerMonth','allocatedleaves','usedleaves.1','leave_PercentagALL','LeavePercntagenew'])

# %%
data.columns
# Out:
# Index(['Age', 'Level2Code', 'JobCategoryCode', 'DesignationCode', 'tenure',
#        'TravelModeCode', 'Resign', 'EmploymentTypeCode', 'PromotionTypeId',
#        'ReportingPersonCode', 'ReportingDesignationCode', 'allocated_leaves',
#        'usedleaves', 'AbsentiesmPercentage', 'AverageMonthlyWorkhrs',
#        'HolidayworkingPercentage'],
#       dtype='object')

# %%
import sklearn as sl
X = data.drop(['Resign'], axis=1)
Y = data['Resign']
Y
X
# Out:
#      Age  Level2Code  JobCategoryCode  DesignationCode  tenure  \
# 0     31           6              133             9032       8
# 1     33           6              134             8935       1
# 2     36           6              134             8935       3
# 3     26           6              134             9057       1
# 4      1          11              139             9000       0
# ..   ...         ...              ...              ...     ...
# 285   34           6              134             8935       0
# 286   35           6              133             9008       6
# 287   30           6              134             8982       1
# 288   36           6              133             9089       9
# 289   32           7              140             9027       2
#
#      TravelModeCode  EmploymentTypeCode  PromotionTypeId  ReportingPersonCode  \
# 0                 2                  54              1.0                17127
# 1                 0                  54              0.0                17135
# 2                 0                  54              0.0                17137
# 3                 0                  54              0.0                17350
# 4                 0                  97              0.0                17310
# ..              ...                 ...              ...                  ...
# 285               0                  47              0.0                17255
# 286               2                  54              1.0                17175
# 287               0                  54              0.0                17188
# 288               2                  54              1.0                17127
# 289               0                  47              1.0                17104
#
#      ReportingDesignationCode  allocated_leaves  usedleaves  \
# 0                        8986             268.0       118.5
# 1                        9087              38.0         3.5
# 2                        8977              70.0         9.5
# 3                        9128              49.0         4.0
# 4                        9150               2.0         0.0
# ..                        ...               ...         ...
# 285                      9017               2.5         0.0
# 286                      9008             216.0        89.0
# 287                      8954              70.0         1.0
# 288                      8986             311.0        72.5
# 289                      8986              91.0         0.0
#
#      AbsentiesmPercentage  AverageMonthlyWorkhrs  HolidayworkingPercentage
# 0               -0.133324             472.020000                 -0.364626
# 1                2.232176               3.560000                 -0.568251
# 2                0.000000             166.585574                  0.000000
# 3                0.203408             189.060000                  0.024114
# 4                0.000000             166.585574                  0.000000
# ..                    ...                    ...                       ...
# 285              1.177510              23.460000                 -0.568251
# 286             -0.012414             143.810000                 -0.568251
# 287              0.000000             166.585574                  0.000000
# 288              0.495990             247.130000                 -0.568251
# 289              2.424039               0.000000                 -0.568251
#
# [284 rows x 15 columns]

# %%
from sklearn.model_selection import train_test_split
# Split the data into a 70% training set and a 30% testing set
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# Print the shapes of the resulting datasets
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (198, 15)
# X_test shape: (86, 15)
# y_train shape: (198,)
# y_test shape: (86,)

# %%
#Random Forest
#Logistic Regression
#KNN
#Gausian Naive Bayes
#Decision Tree
#Support Vector Machine

# %%
# Import necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn import svm
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Create and train a Random Forest model
RMmodel = RandomForestClassifier()
RMmodel.fit(X_train, y_train)

# Make predictions on the test set
y_predRF = RMmodel.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_predRF)
print(f'Accuracy of Random Forest: {accuracy:.2f}')

# Generate a confusion matrix
cm = confusion_matrix(y_test, y_predRF)

# Create a heatmap of the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Random forest Confusion Matrix')
plt.show()
# Out:
# Accuracy of Random Forest: 0.83

# %%
# Create and train a logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# Make predictions on the test set
y_predLR = model.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_predLR)
print(f'Accuracy of Logistic Reggression : {accuracy:.2f}')

# Generate a confusion matrix
cm = confusion_matrix(y_test, y_predLR)

# Create a heatmap of the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="GnBu")
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Logistic Regression Confusion Matrix')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy of Logistic Reggression : 0.63

# %%
# Create and train a Decision Tree model
model = DecisionTreeClassifier()
model.fit(X_train, y_train)

# Make predictions on the test set
y_predDT = model.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_predDT)
print(f'Accuracy of Decision Tree: {accuracy:.2f}')

# Generate a confusion matrix
cm = confusion_matrix(y_test, y_predDT)

# Create a heatmap of the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Reds")
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Decision Tree Confusion Matrix')
plt.show()
# Out:
# Accuracy of Decision Tree: 0.67

# %%
# Create and train a KNN model
model = KNeighborsClassifier()
model.fit(X_train, y_train)

# Make predictions on the test set
y_predKC = model.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_predKC)
print(f'Accuracy of KNN : {accuracy:.2f}')

# Generate a confusion matrix
cm = confusion_matrix(y_test, y_predKC)

# Create a heatmap of the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Greens")
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('KNN Confusion Matrix')
plt.show()
# Out:
# Accuracy of KNN : 0.67

# %%
from os import GRND_NONBLOCK
# Create and train a Naive Bayes (Gaussian Naive Bayes) model
GNBmodel = GaussianNB()
GNBmodel.fit(X_train, y_train)

# Make predictions on the test set
y_predGN = GNBmodel.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_predGN)
print(f'Accuracy of Gaussian Naive Bayes : {accuracy:.2f}')

# Generate a confusion matrix
cm = confusion_matrix(y_test, y_predGN)

# Create a heatmap of the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Oranges")
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Gaussian Naive Bayes Confusion Matrix')
plt.show()
# Out:
# Accuracy of Gaussian Naive Bayes : 0.72

# %%
from sklearn.svm import SVC
# Create and train a Support Vector Machine (SVM) model
model = SVC()
model.fit(X_train, y_train)

# Make predictions on the test set
y_predSVM = model.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_predSVM)
print(f'Accuracy: {accuracy:.2f}')

# Generate a confusion matrix
cm = confusion_matrix(y_test, y_predSVM)

# Create a heatmap of the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Set3")
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Accuracy: 0.58

# %%
#Evaluating the model
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
# Initialize and train the models
models = {
    'Random Forest': RandomForestClassifier(),
    'Logistic Regression': LogisticRegression(),
    'Gaussian Naive Bayes': GaussianNB(),
    'KNN Classification': KNeighborsClassifier(),
    'Decision Tree': DecisionTreeClassifier(),
    'Support Vector machine': SVC()
}

results = []

for model_name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    results.append({
        'Model': model_name,
        'Accuracy': accuracy,
        'Precision': precision,
        'Recall': recall,
        'F1-Score': f1
    })

# Create a DataFrame to display the results
results_df = pd.DataFrame(results)
print(results_df)
# Out:
#                     Model  Accuracy  Precision  Recall  F1-Score
# 0           Random Forest  0.779070   0.771930    0.88  0.822430
# 1     Logistic Regression  0.627907   0.650000    0.78  0.709091
# 2    Gaussian Naive Bayes  0.720930   0.732143    0.82  0.773585
# 3      KNN Classification  0.674419   0.671875    0.86  0.754386
# 4           Decision Tree  0.662791   0.723404    0.68  0.701031
# 5  Support Vector machine  0.581395   0.581395    1.00  0.735294
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Create a DataFrame with the model performance metrics
data = {
    'Model': ['Random Forest', 'Logistic Regression', 'Gaussian Naive Bayes', 'KNN Classification','Decision Tree','SVM'],
    'Accuracy': [0.83, 0.66, 0.72, 0.67,0.62,0.58],
    'Precision': [0.83, 0.66, 0.73, 0.67,0.66,0.58],
    'Recall': [0.90, 0.86, 0.82, 0.86,0.72,0.9],
    'F1-Score':[0.86, 0.75, 0.77, 0.75,0.69,0.73]

}

df = pd.DataFrame(data)

# Set the model names as the index for the DataFrame
df.set_index('Model', inplace=True)

# Define custom colors for the bars
colors = ['#1f77b4', '#aec7e8', '#9467bd', '#c5b0d5']

# Create a bar graph with custom colors
df.plot(kind='bar', figsize=(10, 6), color=colors)
plt.title('Model Performance Metrics')
plt.xlabel('Model')
plt.ylabel('Score')
plt.xticks(rotation=0)  # Rotate x-axis labels for better readability

plt.legend(loc='upper right')
plt.tight_layout()
plt.show()
#RM: 0.79
#gnb : 0.75

# %%
from sklearn.model_selection import train_test_split, GridSearchCV

# Make predictions on both training and testing data
y_train_pred = RMmodel.predict(X_train)
y_test_pred = RMmodel.predict(X_test)

# Calculate accuracy on both datasets
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

# Determine if the model is overfit, underfit, or well-fit
if train_accuracy > test_accuracy:
    print("Model is likely overfitting.")
elif train_accuracy < test_accuracy:
    print("Model is likely underfitting.")
else:
    print("Model is performing well on both training and testing data.")

# Calculate the overfit percentage
overfit_percentage = (train_accuracy - test_accuracy) / train_accuracy * 100

print(f'Training Accuracy: {train_accuracy:.2f}')
print(f'Testing Accuracy: {test_accuracy:.2f}')
print(f'Overfit Percentage: {overfit_percentage:.2f}%')
# Out:
# Model is likely overfitting.
# Training Accuracy: 1.00
# Testing Accuracy: 0.83
# Overfit Percentage: 17.44%

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Perform GridSearchCV
grid_search = GridSearchCV(estimator=RMmodel, param_grid=param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Train the model with the best hyperparameters
best_rf_classifier = RandomForestClassifier(random_state=42, **best_params)
best_rf_classifier.fit(X_train, y_train)

# Make predictions on the test set
y_pred = best_rf_classifier.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Test Accuracy of Random Forest:", accuracy)
# Out:
# Best Hyperparameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
# Test Accuracy of Random Forest: 0.813953488372093

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
# Make predictions on both training and testing (or validation) data
y_train_pred = best_rf_classifier.predict(X_train)
y_test_pred = best_rf_classifier.predict(X_test)

# Calculate accuracy on both datasets
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

# Determine if the model is overfit, underfit, or well-fit
if train_accuracy > test_accuracy:
    print("Model is likely overfitting.")
elif train_accuracy < test_accuracy:
    print("Model is likely underfitting.")
else:
    print("Model is performing well on both training and testing data.")

# Calculate the overfit percentage
overfit_percentage = (train_accuracy - test_accuracy) / train_accuracy * 100

print(f'Training Accuracy: {train_accuracy:.2f}')
print(f'Testing Accuracy: {test_accuracy:.2f}')
print(f'Overfit Percentage: {overfit_percentage:.2f}%')
# Out:
# Model is likely overfitting.
# Training Accuracy: 0.98
# Testing Accuracy: 0.80
# Overfit Percentage: 18.11%

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Create and train a KNN model
model = KNeighborsClassifier()
model.fit(X_train, y_train)

# Make predictions on both training and testing data
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Calculate accuracy on both datasets
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

# Determine if the model is overfit, underfit, or well-fit
if train_accuracy > test_accuracy:
    print("Model is likely overfitting.")
elif train_accuracy < test_accuracy:
    print("Model is likely underfitting.")
else:
    print("Model is performing well on both training and testing data.")

# Calculate the overfit percentage
overfit_percentage = (train_accuracy - test_accuracy) / train_accuracy * 100

print(f'Training Accuracy: {train_accuracy:.2f}')
print(f'Testing Accuracy: {test_accuracy:.2f}')
print(f'Overfit Percentage: {overfit_percentage:.2f}%')
# Out:
# Model is likely overfitting.
# Training Accuracy: 0.85
# Testing Accuracy: 0.67
# Overfit Percentage: 20.99%

# %%
####GNB
# Make predictions on both training and testing data
y_train_pred = GNBmodel.predict(X_train)
y_test_pred = GNBmodel.predict(X_test)

# Calculate accuracy on both datasets
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

# Determine if the model is overfit, underfit, or well-fit
if train_accuracy > test_accuracy:
    print("Model is likely overfitting.")
elif train_accuracy < test_accuracy:
    print("Model is likely underfitting.")
else:
    print("Model is performing well on both training and testing data.")

# Calculate the overfit percentage
overfit_percentage = (train_accuracy - test_accuracy) / train_accuracy * 100

print(f'Training Accuracy: {train_accuracy:.2f}')
print(f'Testing Accuracy: {test_accuracy:.2f}')
print(f'Overfit Percentage: {overfit_percentage:.2f}%')
# Out:
# Model is likely overfitting.
# Training Accuracy: 0.78
# Testing Accuracy: 0.72
# Overfit Percentage: 7.31%

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB
# Define hyperparameters to tune
param_grid = {
    'var_smoothing': [1e-10, 1e-9, 1e-8, 1e-7, 1e-6,1e-5,0,1e+1,1e+2]
}

# Use GridSearchCV for hyperparameter tuning
grid_search = GridSearchCV(GNBmodel, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Get the best model with optimal hyperparameters
best_GNBmodel = grid_search.best_estimator_

# Make predictions on both training and testing data
y_train_pred = best_GNBmodel.predict(X_train)
y_test_pred = best_GNBmodel.predict(X_test)

# Calculate accuracy on both datasets
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

# Determine if the model is overfit, underfit, or well-fit
if train_accuracy > test_accuracy:
    print("Model is likely overfitting.")
elif train_accuracy < test_accuracy:
    print("Model is likely underfitting.")
else:
    print("Model is performing well on both training and testing data.")

# Calculate the overfit percentage
overfit_percentage = (train_accuracy - test_accuracy) / train_accuracy * 100

print(f'Training Accuracy: {train_accuracy:.2f}')
print(f'Testing Accuracy: {test_accuracy:.2f}')
print(f'Overfit Percentage: {overfit_percentage:.2f}%')
# Out:
# Model is likely overfitting.
# Training Accuracy: 0.77
# Testing Accuracy: 0.74
# Overfit Percentage: 3.69%

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import GaussianNB
import numpy as np


# Define the parameter grid for var_smoothing
param_grid = {'var_smoothing': np.logspace(1e-9, -9, num=10)}

# Create a Gaussian Naive Bayes classifier
GNB_Model = GaussianNB()

# Perform grid search with 3-fold cross-validation
grid_search = GridSearchCV(GNB_Model, param_grid, cv=3, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Print the best hyperparameter value
best_var_smoothing = grid_search.best_params_['var_smoothing']
print(f'Best var_smoothing: {best_var_smoothing:.4e}')

# Print the mean cross-validated accuracy with the best hyperparameter
best_mean_accuracy = grid_search.best_score_
print(f"Mean Cross-Validation Accuracy with Best Hyperparameter: {best_mean_accuracy:.4f}")

# Train the model on the entire training dataset with the best hyperparameter
best_GNB_Model = GaussianNB(var_smoothing=best_var_smoothing)
best_GNB_Model.fit(X_train, y_train)

# Make predictions on the test dataset
y_pred_best = best_GNB_Model.predict(X_test)

# Calculate accuracy on the test dataset
accuracy_best = accuracy_score(y_test, y_pred_best)
print(f'Accuracy on the Test Dataset with Best Hyperparameter: {accuracy_best:.4f}')

# Determine if the model is overfit, underfit, or well-fit with the best hyperparameter
tolerance = 1e-4  # You can adjust the tolerance based on your needs
if best_mean_accuracy - accuracy_best > tolerance:
    print("Model is likely overfitting.")
    overfit_percentage = ((best_mean_accuracy - accuracy_best) / best_mean_accuracy) * 100
    print(f'Overfit Percentage: {overfit_percentage:.2f}%')
elif accuracy_best - best_mean_accuracy > tolerance:
    print("Model is likely underfitting.")
    underfit_percentage = ((accuracy_best - best_mean_accuracy) / best_mean_accuracy) * 100
    print(f'Underfit Percentage: {underfit_percentage:.2f}%')
else:
    print("Model is well-fit, performing consistently with cross-validation and the test dataset.")
# Out:
# Best var_smoothing: 2.7364e-06
# Mean Cross-Validation Accuracy with Best Hyperparameter: 0.7778
# Accuracy on the Test Dataset with Best Hyperparameter: 0.7209
# Model is likely overfitting.
# Overfit Percentage: 7.31%

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import GaussianNB
import numpy as np
from sklearn.model_selection import cross_val_score, StratifiedKFold


# Define the parameter grid for var_smoothing
param_grid = {'var_smoothing': np.logspace(1e-9, -9, num=100)}

# Create a Gaussian Naive Bayes classifier
GNB_Model = GaussianNB()

# Perform grid search with 5-fold cross-validation
grid_search = GridSearchCV(GNB_Model, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Print the best hyperparameter value
best_var_smoothing = grid_search.best_params_['var_smoothing']
print(f'Best var_smoothing: {best_var_smoothing:.4e}')

# Print the mean cross-validated accuracy with the best hyperparameter
best_mean_accuracy = grid_search.best_score_
print(f"Mean Cross-Validation Accuracy with Best Hyperparameter: {best_mean_accuracy:.4f}")

# Train the model on the entire training dataset with the best hyperparameter
best_GNB_Model = GaussianNB(var_smoothing=best_var_smoothing)
best_GNB_Model.fit(X_train, y_train)

# Make predictions on the test dataset
y_pred_best = best_GNB_Model.predict(X_test)

# Calculate accuracy on the test dataset
accuracy_best = accuracy_score(y_test, y_pred_best)
print(f'Accuracy on the Test Dataset with Best Hyperparameter: {accuracy_best:.4f}')

# Determine if the model is overfit, underfit, or well-fit with the best hyperparameter
tolerance = 1e-4  # You can adjust the tolerance based on your needs
if best_mean_accuracy - accuracy_best > tolerance:
    print("Model is likely overfitting.")
    overfit_percentage = ((best_mean_accuracy - accuracy_best) / best_mean_accuracy) * 100
    print(f'Overfit Percentage: {overfit_percentage:.2f}%')
elif accuracy_best - best_mean_accuracy > tolerance:
    print("Model is likely underfitting.")
    underfit_percentage = ((accuracy_best - best_mean_accuracy) / best_mean_accuracy) * 100
    print(f'Underfit Percentage: {underfit_percentage:.2f}%')
else:
    print("Model is well-fit, performing consistently with cross-validation and the test dataset.")
# Out:
# Best var_smoothing: 4.3288e-05
# Mean Cross-Validation Accuracy with Best Hyperparameter: 0.7677
# Accuracy on the Test Dataset with Best Hyperparameter: 0.7442
# Model is likely overfitting.
# Overfit Percentage: 3.06%

# %%
###decision tree
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Create and train a Decision Tree model
model = DecisionTreeClassifier()
model.fit(X_train, y_train)

# Make predictions on both training and testing data
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Calculate accuracy on both datasets
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

# Calculate fitting percentages
fitting_percentage_train = (1 - train_accuracy) * 100
fitting_percentage_test = (1 - test_accuracy) * 100

# Determine if the model is overfit, underfit, or well-fit
if train_accuracy > test_accuracy:
    print("Model is likely overfitting.")
elif train_accuracy < test_accuracy:
    print("Model is likely underfitting.")
else:
    print("Model is performing well on both training and testing data.")

# Calculate the overfit percentage
overfit_percentage = (train_accuracy - test_accuracy) / train_accuracy * 100

print(f'Training Accuracy: {train_accuracy:.2f}')
print(f'Testing Accuracy: {test_accuracy:.2f}')
print(f'Overfit Percentage: {overfit_percentage:.2f}%')
# Out:
# Model is likely overfitting.
# Training Accuracy: 1.00
# Testing Accuracy: 0.70
# Overfit Percentage: 30.23%

# %%
from sklearn.model_selection import GridSearchCV

# Define the hyperparameters to tune
param_grid = {
    'max_depth': [None, 10, 20, 30],  # You can adjust these values based on your dataset
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2']
}

# Create and train a Decision Tree model with GridSearchCV for hyperparameter tuning
grid_search = GridSearchCV(DecisionTreeClassifier(), param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Get the best hyperparameters from the grid search
best_params = grid_search.best_params_

# Create a Decision Tree model with the best hyperparameters
best_model = DecisionTreeClassifier(**best_params)
best_model.fit(X_train, y_train)

# Make predictions on both training and testing data
y_train_pred = best_model.predict(X_train)
y_test_pred = best_model.predict(X_test)

# Calculate accuracy on both datasets
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

# %%
# Determine if the model is overfit, underfit, or well-fit
if train_accuracy > test_accuracy:
    print("Model is likely overfitting.")
elif train_accuracy < test_accuracy:
    print("Model is likely underfitting.")
else:
    print("Model is performing well on both training and testing data.")

# Calculate the overfit percentage
overfit_percentage = (train_accuracy - test_accuracy) / train_accuracy * 100

print(f'Best Hyperparameters: {best_params}')
print(f'Training Accuracy: {train_accuracy:.2f}')
print(f'Testing Accuracy: {test_accuracy:.2f}')
print(f'Overfit Percentage: {overfit_percentage:.2f}%')
# Out:
# Model is likely overfitting.
# Best Hyperparameters: {'max_depth': 30, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# Training Accuracy: 0.95
# Testing Accuracy: 0.67
# Overfit Percentage: 28.97%

# %%
###############################deployement##############################################

# %%
#######conditional probability######################

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.naive_bayes import GaussianNB

# Prepare input features for prediction
input_data_employeeA = pd.DataFrame({
    'Age': [55],
    'Level2Code': [6],
    'JobCategoryCode': [134],
    'DesignationCode': [9011],
    'tenure': [0],
    'TravelModeCode': [0],
    'EmploymentTypeCode': [54],
    'PromotionTypeId': [0],
    'ReportingPersonCode': [17099],
    'ReportingDesignationCode': [9065],
    'allocated_leaves': [28],
    'usedleaves': [1],
    'AbsentiesmPercentage': [34.03],
    'AverageMonthlyWorkhrs': [159.45],
    'HolidayworkingPercentage': [45],
})

# Use the model to make predictions
predicted_attrition = best_GNB_Model.predict(input_data_employeeA)

# Interpret the predictions
if predicted_attrition == 1:
    print("The model predicts that the employee is likely to leave the company.")
else:
    print("The model predicts that the employee is likely to stay with the company.")


# Analyze the impact of each feature for the specific employee
class_0_means = best_GNB_Model.theta_[0]
class_1_means = best_GNB_Model.theta_[1]

# Ensure that feature_names is a list
feature_names = input_data_employeeA.columns.tolist()

# Calculate the absolute differences in means between the classes
mean_diff = abs(class_1_means - class_0_means)

# Identify the most affected feature
most_affected_feature = feature_names[mean_diff.argmax()]

print(f"The most affected feature for the specific employee is: {most_affected_feature}")

# Plot the impact of each feature
fig, ax = plt.subplots()
ax.barh(feature_names, mean_diff)
ax.set_title("Impact of Each Feature on Predictions")
plt.show()
# Out:
# The model predicts that the employee is likely to leave the company.
# The most affected feature for the specific employee is: ReportingPersonCode

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.naive_bayes import GaussianNB

# Prepare input features for prediction
input_data_employeeB = pd.DataFrame({
    'Age': [19],
    'Level2Code': [6],
    'JobCategoryCode': [139],
    'DesignationCode': [9032],
    'tenure': [1],
    'TravelModeCode': [4],
    'EmploymentTypeCode': [54],
    'PromotionTypeId': [1],
    'ReportingPersonCode': [17310],
    'ReportingDesignationCode': [9128],
    'allocated_leaves': [30],
    'usedleaves': [5],
    'AbsentiesmPercentage': [2.4],
    'AverageMonthlyWorkhrs': [189],
    'HolidayworkingPercentage': [0],
})

# Use the model to make predictions
predicted_attrition = best_GNB_Model.predict(input_data_employeeB)

# Interpret the predictions
if predicted_attrition == 1:
    print("The model predicts that the employee is likely to leave the company.")
else:
    print("The model predicts that the employee is likely to stay with the company.")

# Analyze the impact of each feature using class conditional probabilities
class_0_means = best_GNB_Model.theta_[0]
class_1_means = best_GNB_Model.theta_[1]

feature_names = input_data_employeeB.columns
feature_impact = class_1_means - class_0_means

# Plot the impact of each feature
fig, ax = plt.subplots()
ax.barh(feature_names, feature_impact)
ax.set_title("Impact of Each Feature on Predictions")
plt.show()
# Out:
# The model predicts that the employee is likely to leave the company.

# %%
#################################bayes theorem############################################

# %%
import pandas as pd
from sklearn.naive_bayes import GaussianNB


# Prepare input features for a specific employee
input_data_employee = pd.DataFrame({
    'Age': [45],
    'Level2Code': [11],
    'JobCategoryCode': [139],
    'DesignationCode': [9032],
    'tenure': [1],
    'TravelModeCode': [0],
    'EmploymentTypeCode': [54],
    'PromotionTypeId': [1],
    'ReportingPersonCode': [17310],
    'ReportingDesignationCode': [9128],
    'allocated_leaves': [2.5],
    'usedleaves': [9.5],
    'AbsentiesmPercentage': [2.4],
    'AverageMonthlyWorkhrs': [189],
    'HolidayworkingPercentage': [0.02],
})

# Get the class prior probabilities
class_priors = GNB_Model.class_prior_

# Get the probabilities of each feature given the class
feature_probabilities = GNB_Model.predict_proba(input_data_employee)

# Calculate the posterior probability for each class
posterior_probabilities = class_priors * feature_probabilities.prod(axis=1)

# Identify the most affecting attribute based on the highest posterior probability
most_affecting_attribute = X.columns[feature_probabilities.argmax(axis=1)]

# Display the most affecting attribute
print(f"\nThe most affecting attribute(s) for the chosen employee is/are: {most_affecting_attribute}")


# Use the model to make predictions
predicted_attrition = GNB_Model.predict(input_data_employee)

# Interpret the predictions
if predicted_attrition == 1:
    print("The model predicts that the employee is likely to leave the company.")
else:
    print("The model predicts that the employee is likely to stay with the company.")
# Out:
# The most affecting attribute(s) for the chosen employee is/are: Index(['Age'], dtype='object')
# The model predicts that the employee is likely to stay with the company.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.naive_bayes import GaussianNB

# Prepare input features for prediction
input_data_employee = pd.DataFrame({
    'Age': [38],
    'Level2Code': [11],
    'JobCategoryCode': [139],
    'DesignationCode': [9032],
    'tenure': [1],
    'TravelModeCode': [0],
    'EmploymentTypeCode': [54],
    'PromotionTypeId': [1],
    'ReportingPersonCode': [17310],
    'ReportingDesignationCode': [9128],
    'allocated_leaves': [98],
    'usedleaves': [94],
    'AbsentiesmPercentage': [24],
    'AverageMonthlyWorkhrs': [189],
    'HolidayworkingPercentage': [0],
})

# Use the model to make predictions
predicted_attrition = best_GNB_Model.predict(input_data_employee)

# Interpret the predictions
if predicted_attrition == 1:
    print("The model predicts that the employee is likely to leave the company.")
else:
    print("The model predicts that the employee is likely to stay with the company.")

# Get the class prior probabilities
class_priors = best_GNB_Model.class_prior_

# Get the probabilities of each feature given the class
feature_probabilities = best_GNB_Model.predict_proba(input_data_employee)

# Calculate the posterior probability for each class
posterior_probabilities = class_priors * feature_probabilities.prod(axis=1)

# Identify the most affecting attribute based on the highest posterior probability
most_affecting_attribute = input_data_employee.columns[feature_probabilities.argmax()]

# Display the most affecting attribute
print(f"\nThe most affecting attribute for the chosen employee is: {most_affecting_attribute}")     #level02: level of the job position
# Out:
# The model predicts that the employee is likely to leave the company.
#
# The most affecting attribute for the chosen employee is: Level2Code

# %%
###############################PCA####################################################

# %%
import pandas as pd
from sklearn.naive_bayes import GaussianNB
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Assuming X_train and y_train are your training features and labels
best_GNB_Model.fit(X_train, y_train)

model_feature_names = [
    'Age','Level2Code','JobCategoryCode','DesignationCode','tenure','TravelModeCode','EmploymentTypeCode','PromotionTypeId','ReportingPersonCode',
    'ReportingDesignationCode','allocated_leaves','usedleaves','AbsentiesmPercentage','AverageMonthlyWorkhrs','HolidayworkingPercentage',
]
# Prepare input features for prediction
input_data_employeeM = pd.DataFrame({
    'Age': [38],
    'Level2Code': [11],
    'JobCategoryCode': [139],
    'DesignationCode': [9032],
    'tenure': [1],
    'TravelModeCode': [0],
    'EmploymentTypeCode': [54],
    'PromotionTypeId': [1],
    'ReportingPersonCode': [17310],
    'ReportingDesignationCode': [9128],
    'allocated_leaves': [98],
    'usedleaves': [94],
    'AbsentiesmPercentage': [24],
    'AverageMonthlyWorkhrs': [189],
    'HolidayworkingPercentage': [0],
})

# Handle NaN values (replace NaN with mean or use another imputation method)
input_data_employeeA.fillna(input_data_employeeM.mean(), inplace=True)

# Apply PCA with standard scaling
scaler = StandardScaler()
scaled_data = scaler.fit_transform(input_data_employeeM)
pca = PCA(n_components=0.95)

try:
    principalComponents = pca.fit_transform(scaled_data)

    # Explain the importance of each attribute using PCA
    for i in range(len(pca.explained_variance_ratio_)):
        print('Attribute: ', model_feature_names[i], ', Importance: ', pca.explained_variance_ratio_[i])

    # Use the model to make predictions
    predicted_attrition = best_GNB_Model.predict(input_data_employeeA)

    # Interpret the predictions
    if predicted_attrition == 1:
        print("The model predicts that the employee is likely to leave the company.")
    else:
        print("The model predicts that the employee is likely to stay with the company.")

except IndexError as e:
    print(f"Error: {e}. Check if there is sufficient variability in the data for PCA.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Attribute:  Age , Importance:  nan
# The model predicts that the employee is likely to leave the company.
# /usr/local/lib/python3.10/dist-packages/sklearn/decomposition/_pca.py:543: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var

# %%
#PCA introduces challenges in interpretability due to its transformation of original features into linear combinations,
#assuming linearity, potentially losing crucial information,
#and may not align with the context of predicting specific outcomes, such as employee attrition.

# %%
###########################################################################################
